# %%
# Source: https://towardsdatascience.com/question-answering-with-bert-xlnet-xlm-and-distilbert-using-simple-transformers-4d8785ee762a

# %%
import json
from simpletransformers.question_answering import QuestionAnsweringModel
import os
# Out:
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ejmejm/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
with open('data/train-v2.0.json', 'r') as f:
    train_data = json.load(f)

train_data = [item for topic in train_data['data'] for item in topic['paragraphs'] ]

# %%
train_args = {
    'learning_rate': 3e-5,
    'num_train_epochs': 2,
    'max_seq_length': 384,
    'doc_stride': 128,
    'overwrite_output_dir': True,
    'reprocess_input_data': False,
    'train_batch_size': 1,
    'gradient_accumulation_steps': 4
}

model = QuestionAnsweringModel('distilbert', 'distilbert-base-uncased-distilled-squad', args=train_args)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9885a738b932> in <module>
#      10 }
#      11
# ---> 12 model = QuestionAnsweringModel('distilbert', 'distilbert-base-uncased-distilled-squad', args=train_args)
#
# ~/anaconda3/lib/python3.6/site-packages/simpletransformers/question_answering/question_answering_model.py in __init__(self, model_type, model_name, args, use_cuda)
#      68         config_class, model_class, tokenizer_class = MODEL_CLASSES[model_type]
#      69         self.tokenizer = tokenizer_class.from_pretrained(model_name)
# ---> 70         self.model = model_class.from_pretrained(model_name)
#      71
#      72         if use_cuda:
#
# ~/anaconda3/lib/python3.6/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     393
#     394         if state_dict is None and not from_tf:
# --> 395             state_dict = torch.load(resolved_archive_file, map_location='cpu')
#     396
#     397         missing_keys = []
#
# ~/anaconda3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     424         if sys.version_info >= (3, 0) and 'encoding' not in pickle_load_args.keys():
#     425             pickle_load_args['encoding'] = 'utf-8'
# --> 426         return _load(f, map_location, pickle_module, **pickle_load_args)
#     427     finally:
#     428         if new_fd:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/serialization.py in _load(f, map_location, pickle_module, **pickle_load_args)
#     618     for key in deserialized_storage_keys:
#     619         assert key in deserialized_objects
# --> 620         deserialized_objects[key]._set_from_file(f, offset, f_should_read_directly)
#     621         if offset is not None:
#     622             offset = f.tell()
#
# KeyboardInterrupt:

# %%
model.train_model(train_data)

# %%
with open('data/dev-v2.0.json', 'r') as f:
    dev_data = json.load(f)

dev_data = [item for topic in dev_data['data'] for item in topic['paragraphs'] ]

preds = model.predict(dev_data[:200])

os.makedirs('results', exist_ok=True)

submission = {pred['id']: pred['answer'] for pred in preds}

with open('results/submission.json', 'w') as f:
    json.dump(submission, f)

# %%
with open('data/dev-v2.0.json', 'r') as f:
    dev_data = json.load(f)
    
dev_data = [item for topic in dev_data['data'] for item in topic['paragraphs'] ]

answer_key = {}
for i in range(len(dev_data)):
    qas = dev_data[i]['qas']
    for entry in qas:
        sa = set([])
        for ae in entry['answers']:
            sa.add(ae['text'])
        
        answer_key[entry['id']] = sa

# %%
total = 0
hit = 0

for key, pred in submission.items():
    answers = answer_key[key]
    if len(answers) == 0:
        continue
        
    if pred in answers:
        hit += 1
    total += 1
    
print(hit, '/', total, '=', float(hit)/total)

# %%
submission
# Out:
# {'56ddde6b9a695914005b9628': 'France.',
#  '56ddde6b9a695914005b9629': '10th and 11th centuries',
#  '56ddde6b9a695914005b962a': 'Denmark, Iceland and Norway',
#  '56ddde6b9a695914005b962b': 'Rollo,',
#  '56ddde6b9a695914005b962c': '10th',
#  '5ad39d53604f3c001a3fe8d1': 'The Normans',
#  '5ad39d53604f3c001a3fe8d2': 'Normandy,',
#  '5ad39d53604f3c001a3fe8d3': 'West Francia.',
#  '5ad39d53604f3c001a3fe8d4': 'first half of the 10th century',
#  '56dddf4066d3e219004dad5f': 'William the Conqueror,',
#  '56dddf4066d3e219004dad60': 'Richard I',
#  '56dddf4066d3e219004dad61': 'Catholic',
#  '5ad3a266604f3c001a3fea27': 'political, cultural and military',
#  '5ad3a266604f3c001a3fea28': 'The Normans',
#  '5ad3a266604f3c001a3fea29': 'The Normans',
#  '5ad3a266604f3c001a3fea2a': 'Richard I',
#  '5ad3a266604f3c001a3fea2b': 'Antioch',
#  '56dde0379a695914005b9636': 'plural of Normant,',
#  '56dde0379a695914005b9637': '9th century',
#  '5ad3ab70604f3c001a3feb89': '"Normans"',
#  '5ad3ab70604f3c001a3feb8a': '9th century',
#  '56dde0ba66d3e219004dad75': '911',
#  '56dde0ba66d3e219004dad76': 'King Charles III of West Francia',
#  '56dde0ba66d3e219004dad77': 'river Seine,',
#  '5ad3ad61604f3c001a3fec0d': '10th century',
#  '5ad3ad61604f3c001a3fec0e': 'treaty of Saint-Clair-sur-Epte',
#  '5ad3ad61604f3c001a3fec0f': 'King Charles III of West Francia and the famed Viking ruler Rollo,',
#  '5ad3ad61604f3c001a3fec10': 'further Viking incursions.',
#  '56dde1d966d3e219004dad8d': "Rollo's",
#  '5ad3ae14604f3c001a3fec39': '880s',
#  '5ad3ae14604f3c001a3fec3a': 'Danes, Norwegians, Norse–Gaels, Orkney Vikings, possibly Swedes, and Anglo-Danes',
#  '56dde27d9a695914005b9651': 'Norse',
#  '56dde27d9a695914005b9652': 'north',
#  '5ad3af11604f3c001a3fec63': 'Catholicism',
#  '5ad3af11604f3c001a3fec64': 'Frankish heritage',
#  '5ad3af11604f3c001a3fec65': 'Old Norse',
#  '56dde2fa66d3e219004dad9b': 'fighting horsemen',
#  '5ad3c626604f3c001a3ff011': 'The Normans',
#  '5ad3c626604f3c001a3ff012': 'fighting horsemen',
#  '5ad3c626604f3c001a3ff013': 'Normans',
#  '56de0f6a4396321400ee257f': 'Pechenegs, the Bulgars, and especially the Seljuk Turks.',
#  '5ad3dbc6604f3c001a3ff3e9': 'the Normans',
#  '5ad3dbc6604f3c001a3ff3ea': 'Pechenegs, the Bulgars, and especially the Seljuk Turks.',
#  '5ad3dbc6604f3c001a3ff3eb': 'Norman mercenaries',
#  '5ad3dbc6604f3c001a3ff3ec': 'Sicilian campaign',
#  '56de0ffd4396321400ee258d': '1050s',
#  '56de0ffd4396321400ee258e': '1060s',
#  '56de0ffd4396321400ee258f': 'Alexius Komnenos.',
#  '5ad3de8b604f3c001a3ff467': 'Hervé',
#  '5ad3de8b604f3c001a3ff468': '1050s',
#  '5ad3de8b604f3c001a3ff469': 'Roussel de Bailleul',
#  '5ad3de8b604f3c001a3ff46a': '1050s. By then however, there were already Norman mercenaries serving as far away as Trebizond and Georgia. They were based at Malatya and Edessa, under the Byzantine duke of Antioch, Isaac Komnenos. In the 1060s,',
#  '56de10b44396321400ee2593': 'Afranji,',
#  '56de10b44396321400ee2594': 'Oursel',
#  '56de10b44396321400ee2595': 'Armenians',
#  '5ad3e96b604f3c001a3ff689': 'Some Normans joined Turkish forces to aid in the destruction of the Armenians vassal-states of Sassoun and Taron in far eastern Anatolia. Later, many took up service with the Armenian state further south in Cilicia and the Taurus Mountains. A Norman named Oursel',
#  '5ad3e96b604f3c001a3ff68a': 'the Armenian state',
#  '5ad3e96b604f3c001a3ff68b': 'Oursel',
#  '5ad3e96b604f3c001a3ff68c': 'upper Euphrates valley in northern Syria.',
#  '56de11154396321400ee25aa': 'Italo-Norman',
#  '5ad3ea79604f3c001a3ff6e9': 'Byzantine Greece',
#  '5ad3ea79604f3c001a3ff6ea': 'George Maniaces',
#  '5ad3ea79604f3c001a3ff6eb': 'Sicilian expedition',
#  '56de148dcffd8e1900b4b5bc': 'Robert Guiscard,',
#  '56de148dcffd8e1900b4b5bd': 'February 1082,',
#  '56de148dcffd8e1900b4b5be': '30,000',
#  '5ad3ed26604f3c001a3ff799': 'Robert Guiscard,',
#  '5ad3ed26604f3c001a3ff79a': 'pope Gregory VII',
#  '5ad3ed26604f3c001a3ff79b': '',
#  '5ad3ed26604f3c001a3ff79c': '30,000',
#  '56de15104396321400ee25b7': 'Deabolis.',
#  '56de15104396321400ee25b8': 'Bohemond,',
#  '56de15104396321400ee25b9': 'river Deabolis,',
#  '5ad3ee2d604f3c001a3ff7e1': 'Dyrrachium',
#  '5ad3ee2d604f3c001a3ff7e2': 'the Normans',
#  '5ad3ee2d604f3c001a3ff7e3': "Robert's",
#  '56de1563cffd8e1900b4b5c2': '1185',
#  '56de1563cffd8e1900b4b5c3': 'Dyrrachium—one',
#  '56de1563cffd8e1900b4b5c4': 'the Adriatic—fell',
#  '5ad3f028604f3c001a3ff823': 'Norman army',
#  '5ad3f028604f3c001a3ff824': 'high Byzantine officials.',
#  '5ad3f028604f3c001a3ff825': 'Dyrrachium—one',
#  '56de15dbcffd8e1900b4b5c8': 'Duke Richard II of Normandy,',
#  '56de15dbcffd8e1900b4b5c9': 'Duke Richard II of Normandy,',
#  '56de15dbcffd8e1900b4b5ca': 'Normandy',
#  '56de15dbcffd8e1900b4b5cb': 'Sweyn Forkbeard.',
#  '5ad3f187604f3c001a3ff86f': 'Emma,',
#  '5ad3f187604f3c001a3ff870': '1013',
#  '5ad3f187604f3c001a3ff871': 'they occupied most of the important ports opposite England across the English Channel.',
#  '56de1645cffd8e1900b4b5d0': 'Harthacnut,',
#  '56de1645cffd8e1900b4b5d1': '1041',
#  '56de1645cffd8e1900b4b5d2': 'Robert of Jumièges',
#  '5ad3f350604f3c001a3ff8ef': '1041',
#  '5ad3f350604f3c001a3ff8f0': 'English cavalry',
#  '5ad3f350604f3c001a3ff8f1': 'He appointed Robert of Jumièges archbishop of Canterbury',
#  '56de16ca4396321400ee25c5': 'Battle of Hastings.',
#  '56de16ca4396321400ee25c6': 'Duke William II of Normandy',
#  '56de16ca4396321400ee25c7': '1066',
#  '56de16ca4396321400ee25c8': 'Anglo-Saxons',
#  '5ad3f4b1604f3c001a3ff951': '1066',
#  '5ad3f4b1604f3c001a3ff952': 'Battle of Hastings.',
#  '5ad3f4b1604f3c001a3ff953': 'Anglo-Saxons',
#  '5ad3f4b1604f3c001a3ff954': 'Early Norman kings of England,',
#  '56de1728cffd8e1900b4b5d7': 'Latin language, something that was the subject of some humour by Geoffrey Chaucer. The Anglo-Norman language was eventually absorbed into the Anglo-Saxon language',
#  '5ad3f5b0604f3c001a3ff9ab': 'the Norman aristocracy',
#  '5ad3f5b0604f3c001a3ff9ac': 'Anglo-Saxon language of their subjects',
#  '5ad3f5b0604f3c001a3ff9ad': 'Geoffrey Chaucer.',
#  '56de179dcffd8e1900b4b5da': '1169',
#  '56de179dcffd8e1900b4b5db': 'Bannow Bay',
#  '56de179dcffd8e1900b4b5dc': 'Irish culture',
#  '5ad3f6f5604f3c001a3ffa09': 'Bannow Bay',
#  '5ad3f6f5604f3c001a3ffa0a': 'Irish culture and history',
#  '5ad3f6f5604f3c001a3ffa0b': 'Trim Castle and Dublin Castle.',
#  '56de17f9cffd8e1900b4b5e0': "Edgar's",
#  '56de17f9cffd8e1900b4b5e1': 'Malcolm III of Scotland',
#  '56de17f9cffd8e1900b4b5e2': '1072',
#  '56de17f9cffd8e1900b4b5e3': 'Duncan',
#  '5ad3f7ac604f3c001a3ffa3b': 'Margaret,',
#  '5ad3f7ac604f3c001a3ffa3c': 'William',
#  '5ad3f7ac604f3c001a3ffa3d': 'Duncan',
#  '56de3cd0cffd8e1900b4b6be': 'Sybilla of Normandy,',
#  '56de3cd0cffd8e1900b4b6bf': 'Normans and Norman',
#  '5ad3f8d2604f3c001a3ffa8d': 'Sybilla of Normandy,',
#  '5ad3f8d2604f3c001a3ffa8e': 'Normans and Norman culture',
#  '56de3d594396321400ee26ca': 'Hereford',
#  '56de3d594396321400ee26cb': 'the Welsh.',
#  '56de3d594396321400ee26cc': 'Edward the Confessor',
#  '5ad3fb01604f3c001a3ffb35': 'the Normans',
#  '5ad3fb01604f3c001a3ffb36': 'Ralph as earl of Hereford',
#  '56de3dbacffd8e1900b4b6d2': 'Cheshire.',
#  '5ad3fb6e604f3c001a3ffb5f': 'the Marches',
#  '5ad3fb6e604f3c001a3ffb60': 'Bernard de Neufmarché, Roger of Montgomery in Shropshire and Hugh Lupus in Cheshire.',
#  '56de3e414396321400ee26d8': '1018',
#  '56de3e414396321400ee26d9': 'William of Montreuil',
#  '5ad3fc41604f3c001a3ffb8f': 'Antioch.',
#  '5ad3fc41604f3c001a3ffb90': 'religious wars',
#  '5ad3fc41604f3c001a3ffb91': 'Roger de Tosny',
#  '5ad3fc41604f3c001a3ffb92': 'War of Barbastro,',
#  '56de3ebc4396321400ee26e6': '1097',
#  '56de3ebc4396321400ee26e7': 'Tancred',
#  '56de3ebc4396321400ee26e8': 'Jerusalem',
#  '5ad4017a604f3c001a3ffd1f': '1097',
#  '5ad4017a604f3c001a3ffd20': 'Bohemond',
#  '56de3efccffd8e1900b4b6fe': '380 years',
#  '5ad401f2604f3c001a3ffd41': 'Cyprus',
#  '5ad401f2604f3c001a3ffd42': 'Anglo-Norman forces of the Third Crusade',
#  '56de3f784396321400ee26fa': 'a storm',
#  '56de3f784396321400ee26fb': 'Berengaria',
#  '56de3f784396321400ee26fc': '1191',
#  '56de3f784396321400ee26fd': 'Richard the Lion-hearted',
#  '5ad40280604f3c001a3ffd57': 'Richard the Lion-hearted',
#  '5ad40280604f3c001a3ffd58': '1191',
#  '5ad40280604f3c001a3ffd59': 'Richard the Lion-hearted',
#  '56de40da4396321400ee2708': 'Conrad of Montferrat.',
#  '56de40da4396321400ee2709': 'silver',
#  '56de40da4396321400ee270a': 'Guy de Lusignan.',
#  '5ad404a6604f3c001a3ffde1': 'silver',
#  '5ad404a6604f3c001a3ffde2': 'Guy de Lusignan.',
#  '5ad404a6604f3c001a3ffde3': 'Isaac,',
#  '56de49564396321400ee277a': 'Africa.',
#  '5ad40419604f3c001a3ffdb7': 'the expedition led by the Norman noble Jean de Bethencourt and the Poitevine Gadifer de la Salle',
#  '5ad40419604f3c001a3ffdb8': 'Lanzarote, Fuerteventura and El Hierro',
#  '56de49a8cffd8e1900b4b7a7': 'Bethencourt',
#  '56de49a8cffd8e1900b4b7a8': 'Enrique Pérez de Guzmán,',
#  '56de49a8cffd8e1900b4b7a9': 'Enrique Pérez de Guzmán,',
#  '5ad403c1604f3c001a3ffd97': 'King of the Canary Islands,',
#  '5ad403c1604f3c001a3ffd98': 'Enrique Pérez de Guzmán,',
#  '56de4a474396321400ee2786': 'Channel Islands.',
#  '56de4a474396321400ee2787': 'two',
#  '5ad40358604f3c001a3ffd7d': 'Très ancien coutumier',
#  '5ad40358604f3c001a3ffd7e': 'Très ancien coutumier',
#  '5ad40358604f3c001a3ffd7f': 'the Grand coutumier de Normandie',
#  '56de4a89cffd8e1900b4b7bd': 'Romanesque idiom',
#  '56de4a89cffd8e1900b4b7be': 'rounded arches',
#  '5ad402ce604f3c001a3ffd67': 'rounded arches',
#  '56de4b074396321400ee2793': 'Early Gothic.',
#  '56de4b074396321400ee2794': 'Early Gothic.',
#  '56de4b074396321400ee2795': 'Kingdom of Sicily.',
#  '5ad400b0604f3c001a3ffcdf': 'Early Gothic.',
#  '5ad400b0604f3c001a3ffce0': 'Norman architecture',
#  '5ad400b0604f3c001a3ffce1': 'the Normans',
#  '56de4b5c4396321400ee2799': 'early 11th century',
#  '56de4b5c4396321400ee279a': 'the dukes',
#  '5ad3ffd7604f3c001a3ffca7': 'visual arts',
#  '5ad3ffd7604f3c001a3ffca8': 'the dukes',
#  '5ad3ffd7604f3c001a3ffca9': 'disparate duchy',
#  '5ad3ffd7604f3c001a3ffcaa': 'Normandy',
#  '56de4bb84396321400ee27a2': '16th century',
#  '5ad3ff1b604f3c001a3ffc73': 'French Wars of Religion',
#  '5ad3ff1b604f3c001a3ffc74': 'French Revolution',
#  '56de4c324396321400ee27ab': 'embroidery',
#  '56de4c324396321400ee27ac': 'the Bayeux Tapestry,',
#  '56de4c324396321400ee27ad': 'Odo, the Bishop of Bayeux and first Earl of Kent,',
#  '5ad3fe91604f3c001a3ffc47': 'the Bayeux Tapestry,',
#  '5ad3fe91604f3c001a3ffc48': 'Odo, the Bishop of Bayeux and first Earl of Kent,',
#  '56de51244396321400ee27ef': 'stonework or metalwork, such as capitals and baptismal fonts. In southern Italy, however, Norman artwork survives plentifully in forms strongly influenced by its Greek, Lombard, and Arab forebears. Of the royal regalia preserved in Palermo, the crown is Byzantine in style and the coronation cloak is of Arab craftsmanship with Arabic inscriptions. Many churches preserve sculptured fonts, capitals, and more importantly mosaics,',
#  '5ad3fe0d604f3c001a3ffc1b': 'as stonework or metalwork',
#  '5ad3fe0d604f3c001a3ffc1c': 'mosaics',
#  '5ad3fe0d604f3c001a3ffc1d': 'Lombard Salerno',
#  '56de51c64396321400ee27f7': '11th',
#  '56de51c64396321400ee27f8': 'William of Volpiano and John of Ravenna,',
#  '5ad3fd68604f3c001a3ffbe7': 'history of classical music',
#  '5ad3fd68604f3c001a3ffbe8': 'musical production and education',
#  '56de52614396321400ee27fb': 'southern Italy,',
#  '56de52614396321400ee27fc': "Sant'Eufemia.",
#  '56de52614396321400ee27fd': 'Robert Guiscard',
#  '56de52614396321400ee27fe': 'singing',
#  '5ad3fccf604f3c001a3ffbb5': 'monks',
#  '56e16182e3433e1400422e28': 'Computational complexity theory',
#  '56e16182e3433e1400422e29': 'inherent difficulty',
#  '56e16182e3433e1400422e2a': 'A computational problem',
#  '5ad5316b5b96ef001a10ab72': 'a branch of the theory of computation in theoretical computer science that focuses on classifying computational problems according to their inherent difficulty, and relating those classes to each other. A computational problem is understood to be a task that is in principle amenable to being solved by a computer,',
#  '5ad5316b5b96ef001a10ab73': 'Computational complexity theory',
#  '5ad5316b5b96ef001a10ab74': 'A computational problem',
#  '5ad5316b5b96ef001a10ab75': 'an algorithm',
#  '5ad5316b5b96ef001a10ab76': 'an algorithm',
#  '56e16839cd28a01900c67887': 'significant resources',
#  '56e16839cd28a01900c67888': 'mathematical models of computation',
#  '56e16839cd28a01900c67889': 'time and storage',
#  '56e16839cd28a01900c6788a': 'gates',
#  '56e16839cd28a01900c6788b': 'to determine the practical limits on what computers can and cannot do',
#  '5ad532575b96ef001a10ab7c': 'amount of communication (used in communication complexity), the number of gates in a circuit (used in circuit complexity) and the number of processors',
#  '5ad532575b96ef001a10ab7d': 'mathematical models of computation',
#  '5ad532575b96ef001a10ab7e': 'time and storage',
#  '5ad532575b96ef001a10ab7f': 'gates',
#  '5ad532575b96ef001a10ab80': 'the number of processors',
#  '56e17644e3433e1400422f40': 'analysis of algorithms and computability theory',
#  '56e17644e3433e1400422f41': 'computability theory',
#  '56e17644e3433e1400422f42': 'computability theory',
#  '56e17644e3433e1400422f43': 'computability theory',
#  '5ad5344b5b96ef001a10ab86': 'analysis of algorithms and computability theory',
#  '5ad5344b5b96ef001a10ab87': 'the former is devoted to analyzing the amount of resources needed by a particular algorithm to solve a problem',
#  '5ad5344b5b96ef001a10ab88': 'computability theory. A key distinction between analysis of algorithms and computational complexity theory',
#  '5ad5344b5b96ef001a10ab89': 'computational complexity theory',
#  '5ad5344b5b96ef001a10ab8a': 'computability theory',
#  '56e17a7ccd28a01900c679a1': 'problem instance',
#  '56e17a7ccd28a01900c679a2': 'a problem',
#  '56e17a7ccd28a01900c679a3': 'concrete',
#  '56e17a7ccd28a01900c679a4': 'output',
#  '56e17a7ccd28a01900c679a5': 'utterance',
#  '5ad5364c5b96ef001a10ab90': 'A computational problem',
#  '5ad5364c5b96ef001a10ab91': 'problem instance',
#  '5ad5364c5b96ef001a10ab92': 'computational complexity theory',
#  '5ad5364c5b96ef001a10ab93': 'the solution',
#  '5ad5364c5b96ef001a10ab94': 'the solution is the output corresponding to the given input',
#  '56e17e6ee3433e1400422f7f': '2000',
#  '56e17e6ee3433e1400422f80': 'asking for a round trip through all sites in Milan',
#  '56e17e6ee3433e1400422f81': 'a round trip through all sites in Milan',
#  '5ad537a15b96ef001a10ab9a': '2000 kilometres',
#  '5ad537a15b96ef001a10ab9b': 'asking for a round trip through all sites in Milan',
#  '5ad537a15b96ef001a10ab9c': 'asking for a round trip through all sites in Milan',
#  '5ad537a15b96ef001a10ab9d': 'a round trip through all sites in Milan',
#  '56e181d9e3433e1400422fa0': 'bitstrings',
#  '56e181d9e3433e1400422fa1': 'a string',
#  '56e181d9e3433e1400422fa2': 'a string over an alphabet',
#  '56e181d9e3433e1400422fa3': 'suitably',
#  '56e181d9e3433e1400422fa4': 'via their adjacency matrices',
#  '5ad5391e5b96ef001a10aba2': 'alphabet',
#  '5ad5391e5b96ef001a10aba3': 'a string',
#  '5ad5391e5b96ef001a10aba4': 'a string over an alphabet',
#  '5ad5391e5b96ef001a10aba5': 'integers',
#  '5ad5391e5b96ef001a10aba6': 'via their adjacency matrices',
#  '56e190bce3433e1400422fc8': 'Decision problems',
#  '56e190bce3433e1400422fc9': 'yes or no, or alternately either 1 or 0',
#  '56e190bce3433e1400422fca': 'yes or no, or alternately either 1 or 0',
#  '56e190bce3433e1400422fcb': 'yes',
#  '56e190bce3433e1400422fcc': 'yes',
#  '5ad53b9d5b96ef001a10abc8': 'Decision problems',
#  '5ad53b9d5b96ef001a10abc9': 'decision problem',
#  '5ad53b9d5b96ef001a10abca': 'A decision problem',
#  '5ad53b9d5b96ef001a10abcb': 'yes or no, or alternately either 1 or 0',
#  '5ad53b9d5b96ef001a10abcc': 'yes',
#  '56e19557e3433e1400422fee': 'arbitrary graph',
#  '56e19557e3433e1400422ff0': 'formal language',
#  '56e19557e3433e1400422ff1': 'the set of all connected graphs',
#  '5ad53d705b96ef001a10abd2': 'arbitrary graph',
#  '5ad53d705b96ef001a10abd3': 'formal language',
#  '5ad53d705b96ef001a10abd4': 'binary strings',
#  '5ad53d705b96ef001a10abd5': 'one has to decide how graphs are encoded as binary strings',
#  '56e19724cd28a01900c679f6': 'computational',
#  '56e19724cd28a01900c679f7': 'single',
#  '56e19724cd28a01900c679f8': 'integer factorization problem',
#  '56e19724cd28a01900c679f9': 'integer factorization problem',
#  '56e19724cd28a01900c679fa': 'complex',
#  '5ad53e615b96ef001a10abda': 'A function problem',
#  '5ad53e615b96ef001a10abdb': 'A function problem',
#  '5ad53e615b96ef001a10abdc': 'traveling salesman problem and the integer factorization problem',
#  '5ad53e615b96ef001a10abdd': 'traveling salesman problem and the integer factorization problem',
#  '5ad53e615b96ef001a10abde': 'complex',
#  '56e1a0dccd28a01900c67a2e': 'decision problems',
#  '56e1a0dccd28a01900c67a2f': 'triples',
#  '5ad53f815b96ef001a10abe4': 'function problems',
#  '5ad53f815b96ef001a10abe5': 'triples',
#  '5ad53f815b96ef001a10abe6': 'Deciding whether a given triple is a member of this set',
#  '56e1a38de3433e140042305c': 'the size of the input in bits',
#  '56e1a38de3433e140042305d': 'the instance',
#  '56e1a38de3433e140042305e': 'as a function of the size of the instance',
#  '56e1a38de3433e140042305f': 'bits',
#  '56e1a38de3433e1400423060': 'input size',
#  '5ad541ad5b96ef001a10abea': 'as a function of the size of the instance',
#  '5ad541ad5b96ef001a10abeb': 'size of the input in bits',
#  '5ad541ad5b96ef001a10abec': 'as a function of the size of the instance',
#  '5ad541ad5b96ef001a10abed': 'Complexity theory',
#  '5ad541ad5b96ef001a10abee': 'as a function of the size of the instance',
#  '56e1a564cd28a01900c67a48': "Cobham's",
#  '56e1a564cd28a01900c67a49': 'the time taken',
#  '56e1a564cd28a01900c67a4a': 'worst-case time complexity T(n)',
#  '56e1a564cd28a01900c67a4b': 'the maximum time taken over all inputs of size n',
#  '56e1a564cd28a01900c67a4c': 'polynomial time algorithm',
#  '5ad542db5b96ef001a10abf4': 'If the input size is n,',
#  '5ad542db5b96ef001a10abf5': "Cobham's",
#  '5ad542db5b96ef001a10abf6': 'worst-case time complexity T(n)',
#  '5ad542db5b96ef001a10abf7': 'the maximum time taken over all inputs of size n',
#  '5ad542db5b96ef001a10abf8': 'polynomial time algorithm',
#  '56e1aba0e3433e1400423094': 'Turing machine',
#  '56e1aba0e3433e1400423095': 'an algorithm',
#  '56e1aba0e3433e1400423097': 'Turing machine',
#  '56e1aba0e3433e1400423098': 'symbols',
#  '5ad543c05b96ef001a10abfe': 'Turing machine',
#  '5ad543c05b96ef001a10abff': 'Turing machine',
#  '5ad543c05b96ef001a10ac00': 'Turing machines',
#  '5ad543c05b96ef001a10ac01': 'Turing machine',
#  '56e1aff7cd28a01900c67a68': 'A deterministic Turing machine',
#  '56e1aff7cd28a01900c67a69': 'rules',
#  '56e1aff7cd28a01900c67a6a': 'randomized algorithms',
#  '56e1aff7cd28a01900c67a6b': 'non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism',
#  '56e1aff7cd28a01900c67a6c': 'randomized algorithms',
#  '5ad546c75b96ef001a10ac0e': 'A deterministic Turing machine',
#  '5ad546c75b96ef001a10ac0f': 'A probabilistic Turing machine',
#  '5ad546c75b96ef001a10ac10': 'The ability to make probabilistic decisions',
#  '5ad546c75b96ef001a10ac11': 'A non-deterministic Turing machine',
#  '5ad546c75b96ef001a10ac12': 'that the Turing machine branches into many possible computational paths at each step,',
#  '56e1b00ce3433e140042309e': 'complexity classes',
#  '56e1b00ce3433e140042309f': 'when resources (such as time or space) are bounded',
#  '56e1b00ce3433e14004230a1': 'deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines.',
#  '5ad545545b96ef001a10ac06': 'to define complexity classes',
#  '5ad545545b96ef001a10ac07': 'when resources (such as time or space) are bounded',
#  '5ad545545b96ef001a10ac08': 'deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines.',
#  '5ad545545b96ef001a10ac09': 'bounded',
#  '56e1b169cd28a01900c67a72': 'random access machines',
#  '56e1b169cd28a01900c67a73': 'time and memory',
#  '56e1b169cd28a01900c67a74': 'time and memory',
#  '56e1b169cd28a01900c67a75': 'deterministically',
#  '5ad547945b96ef001a10ac18': 'random access machines',
#  '5ad547945b96ef001a10ac19': 'time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.',
#  '5ad547945b96ef001a10ac1a': 'time and memory',
#  '5ad547945b96ef001a10ac1b': 'the machines operate deterministically',
#  '56e1b355e3433e14004230b0': 'non-deterministic',
#  '56e1b355e3433e14004230b1': 'more unusual resources',
#  '56e1b355e3433e14004230b2': 'mathematical models',
#  '56e1b355e3433e14004230b3': 'non-deterministic time',
#  '5ad5489b5b96ef001a10ac2a': 'computational problems',
#  '5ad5489b5b96ef001a10ac2b': 'non-deterministic Turing machine',
#  '5ad5489b5b96ef001a10ac2c': 'The non-deterministic Turing machine has very little to do',
#  '5ad5489b5b96ef001a10ac2d': 'non-deterministic Turing machine',
#  '5ad5489b5b96ef001a10ac2e': 'non-deterministic time',
#  '56e1b62ecd28a01900c67aa3': '"yes" or "no"',
#  '56e1b62ecd28a01900c67aa4': 'difficulty',
#  '56e1b62ecd28a01900c67aa5': 'DTIME(f(n)).',
#  '56e1b62ecd28a01900c67aa6': 'complexity theory',
#  '5ad54a375b96ef001a10ac48': 'a computational model',
#  '5ad54a375b96ef001a10ac49': 'within time f(n)',
#  '5ad54a375b96ef001a10ac4a': 'DTIME(f(n)).',
#  '5ad54a375b96ef001a10ac4b': 'DTIME(f(n)).',
#  '5ad54a375b96ef001a10ac4c': 'if there exists a Turing machine operating in time f(n) that solves the problem.',
#  '56e1b754cd28a01900c67abc': 'complexity',
#  '56e1b754cd28a01900c67abd': 'computational',
#  '56e1b754cd28a01900c67abe': 'Blum complexity axioms.',
#  '56e1b754cd28a01900c67abf': 'complexity theory',
#  '56e1b754cd28a01900c67ac0': 'complexity measures',
#  '5ad54b035b96ef001a10ac52': 'Analogous definitions',
#  '5ad54b035b96ef001a10ac53': 'time and space',
#  '5ad54b035b96ef001a10ac54': 'Blum complexity axioms.',
#  '5ad54b035b96ef001a10ac55': 'communication complexity, circuit complexity, and decision tree complexity',
#  '5ad54b035b96ef001a10ac56': 'complexity theory',
#  '56e1b8f3e3433e14004230e6': 'best, worst and average',
#  '56e1b8f3e3433e14004230e7': 'time complexity',
#  '56e1b8f3e3433e14004230e8': 'best, worst and average case complexity refer to three different ways of measuring the time complexity (or any other complexity measure) of different inputs of the same size',
#  '56e1b8f3e3433e14004230e9': 'time complexity',
#  '5ad54c2f5b96ef001a10ac5c': 'best, worst and average',
#  '5ad54c2f5b96ef001a10ac5d': 'The best, worst and average case complexity',
#  '5ad54c2f5b96ef001a10ac5e': 'best, worst and average case complexity refer to three different ways of measuring the time complexity (or any other complexity measure) of different inputs of the same size',
#  '5ad54c2f5b96ef001a10ac5f': 'n',
#  '56e1ba41cd28a01900c67ae0': 'quicksort',
#  '56e1ba41cd28a01900c67ae1': 'worst-case',
#  '56e1ba41cd28a01900c67ae2': 'O(n2)',
#  '5ad54d625b96ef001a10ac64': 'deterministic sorting algorithm quicksort',
#  '5ad54d625b96ef001a10ac65': 'solves the problem of sorting a list of integers that is given as the input',
#  '5ad54d625b96ef001a10ac66': 'O(n2)',
#  '5ad54d625b96ef001a10ac67': 'O(n2)',
#  '5ad54d625b96ef001a10ac68': 'best case',
#  '56e1bc3ae3433e1400423104': 'the most efficient algorithm solving a given problem',
#  '56e1bc3ae3433e1400423105': 'algorithms',
#  '56e1bc3ae3433e1400423106': 'lower bounds',
#  '56e1bc3ae3433e1400423107': 'upper bound',
#  '56e1bc3ae3433e1400423108': '"all possible algorithms"',
#  '5ad54e7c5b96ef001a10ac76': 'space consumption',
#  '5ad54e7c5b96ef001a10ac77': 'The complexity of an algorithm',
#  '5ad54e7c5b96ef001a10ac78': 'Analyzing a particular algorithm',
#  '5ad54e7c5b96ef001a10ac79': 'To show an upper bound T(n) on the time complexity of a problem,',
#  '5ad54e7c5b96ef001a10ac7a': 'lower bounds make a statement about all possible algorithms that solve a given problem',
#  '56e1bd4acd28a01900c67afc': 'big O notation,',
#  '56e1bd4acd28a01900c67afd': 'constant factors and smaller terms',
#  '56e1bd4acd28a01900c67afe': 'if T(n) = 7n2 + 15n + 40,',
#  '56e1bd4acd28a01900c67aff': 'computational model',
#  '5ad54f775b96ef001a10ac88': 'Upper and lower bounds',
#  '5ad54f775b96ef001a10ac89': 'big O notation,',
#  '5ad54f775b96ef001a10ac8a': 'big O notation,',
#  '5ad54f775b96ef001a10ac8b': 'write T(n) = O(n2).',
#  '56e1c0f6cd28a01900c67b2c': 'complexity classes',
#  '56e1c0f6cd28a01900c67b2d': 'complicated definitions',
#  '56e1c0f6cd28a01900c67b2e': 'complicated definitions',
#  '5ad5501f5b96ef001a10ac90': 'complicated definitions',
#  '5ad5501f5b96ef001a10ac91': 'complexity classes',
#  '5ad5501f5b96ef001a10ac92': 'complicated definitions',
#  '5ad5501f5b96ef001a10ac93': 'complicated definitions',
#  '56e1c2eee3433e1400423134': 'the chosen machine model',
#  '56e1c2eee3433e1400423135': 'quadratic time',
#  '56e1c2eee3433e1400423136': 'single-tape',
#  '56e1c2eee3433e1400423137': 'Cobham-Edmonds thesis',
#  '56e1c2eee3433e1400423138': 'complexity class P,',
#  '5ad55ee35b96ef001a10ace4': 'bounding the computation time above by some concrete function f(n)',
#  '5ad55ee35b96ef001a10ace5': 'f(n)',
#  '5ad55ee35b96ef001a10ace6': 'the language {xx | x is any binary string}',
#  '5ad55ee35b96ef001a10ace7': 'xx | x',
#  '5ad55ee35b96ef001a10ace8': 'Cobham-Edmonds thesis',
#  '56e1c3e1e3433e1400423148': 'time or space',
#  '56e1c3e1e3433e1400423149': 'bounding',
#  '56e1c3e1e3433e140042314a': 'important complexity classes',
#  '5ad55fe75b96ef001a10ad0c': 'important complexity classes',
#  '5ad55fe75b96ef001a10ad0d': 'time or space',
#  '5ad55fe75b96ef001a10ad0e': 'bounding the time or space',
#  '5ad55fe75b96ef001a10ad0f': 'time',
#  '56e1c4fce3433e140042314e': 'BPP, ZPP and RP,',
#  '56e1c4fce3433e140042314f': 'Boolean',
#  '56e1c4fce3433e1400423150': 'quantum',
#  '56e1c4fce3433e1400423151': '#P',
#  '56e1c4fce3433e1400423152': 'Interactive',
#  '5ad560b85b96ef001a10ad1e': 'BPP, ZPP and RP,',
#  '5ad560b85b96ef001a10ad1f': 'probabilistic Turing machines;',
#  '5ad560b85b96ef001a10ad20': 'quantum Turing machines.',
#  '5ad560b85b96ef001a10ad21': '#P',
#  '5ad560b85b96ef001a10ad22': 'Interactive proof systems.',
#  '56e1c720e3433e140042316a': 'computation time',
#  '56e1c720e3433e140042316b': 'DTIME(n2),',
#  '56e1c720e3433e140042316c': 'time and space hierarchy theorems',
#  '56e1c720e3433e140042316d': 'a proper hierarchy',
#  '56e1c720e3433e140042316e': 'quantitative',
#  '5ad561c85b96ef001a10ad3c': 'computation time',
#  '5ad561c85b96ef001a10ad3d': 'relaxing the requirements on (say) computation time',
#  '5ad561c85b96ef001a10ad3e': 'DTIME(n2),',
#  '5ad561c85b96ef001a10ad3f': 'hierarchy theorems',
#  '5ad561c85b96ef001a10ad40': 'quantitative',
#  '56e1c7e2cd28a01900c67b74': 'The time and space hierarchy theorems',
#  '56e1c7e2cd28a01900c67b75': 'strictly contained in EXPTIME,',
#  '56e1c7e2cd28a01900c67b76': 'PSPACE.',
#  '5ad562525b96ef001a10ad50': 'The time and space hierarchy theorems',
#  '5ad562525b96ef001a10ad51': 'complexity classes',
#  '5ad562525b96ef001a10ad52': 'P',
#  '5ad562525b96ef001a10ad53': 'L',
#  '56e1c9bfe3433e1400423192': 'a reduction',
#  '56e1c9bfe3433e1400423193': 'another problem',
#  '56e1c9bfe3433e1400423194': 'no more difficult',
#  '56e1c9bfe3433e1400423195': 'Cook reductions, Karp reductions and Levin reductions,',
#  '56e1c9bfe3433e1400423196': 'complexity',
#  '5ad5632f5b96ef001a10ad6c': 'the concept of a reduction',
#  '5ad5632f5b96ef001a10ad6d': 'complexity classes',
#  '5ad5632f5b96ef001a10ad6e': 'A reduction',
#  '5ad5632f5b96ef001a10ad6f': 'A reduction',
#  '5ad5632f5b96ef001a10ad70': 'Cook reductions, Karp reductions and Levin reductions,',
#  '56e1cbe2cd28a01900c67bac': 'polynomial-time reduction',
#  '56e1cbe2cd28a01900c67bad': 'multiplying two integers',
#  '56e1cbe2cd28a01900c67bae': 'squaring an integer can be reduced to the problem of multiplying two integers',
#  '56e1cbe2cd28a01900c67baf': 'both inputs',
#  '56e1cbe2cd28a01900c67bb0': 'multiplication',
#  '5ad5648b5b96ef001a10ad94': 'polynomial-time reduction',
#  '5ad5648b5b96ef001a10ad95': 'the reduction process takes polynomial time',
#  '5ad5648b5b96ef001a10ad96': 'multiplying two integers',
#  '5ad5648b5b96ef001a10ad97': 'squaring',
#  '5ad5648b5b96ef001a10ad98': 'squaring',
#  '56e1ce08e3433e14004231a4': 'the type of reduction being used',
#  '56e1ce08e3433e14004231a5': 'an algorithm for X',
#  '56e1ce08e3433e14004231a6': 'solve any problem in C.',
#  '56e1ce08e3433e14004231a8': 'the set of NP-hard problems.',
#  '5ad565575b96ef001a10adb2': 'the type of reduction being used',
#  '5ad565575b96ef001a10adb3': 'an algorithm for X',
#  '5ad565575b96ef001a10adb4': 'no problem',
#  '5ad565575b96ef001a10adb5': 'the set of NP-hard problems.',
#  '56e1d9fee3433e14004231cb': 'NP-complete',
#  '56e1d9fee3433e14004231cc': 'P.',
#  '56e1d9fee3433e14004231cd': 'finding an NP-complete problem that can be solved in polynomial time',
#  '56e1d9fee3433e14004231ce': 'the set',
#  '5ad566375b96ef001a10adce': 'X is said to be complete',
#  '5ad566375b96ef001a10adcf': 'X',
#  '5ad566375b96ef001a10add0': 'NP-complete',
#  '5ad566375b96ef001a10add1': 'Π2,',
#  '56e1dc62cd28a01900c67bca': 'P',
#  '56e1dc62cd28a01900c67bcb': 'Cobham–Edmonds thesis.',
#  '56e1dc62cd28a01900c67bcc': 'P',
#  '56e1dc62cd28a01900c67bcd': 'Boolean satisfiability problem, the Hamiltonian path problem and the vertex cover problem.',
#  '56e1dc62cd28a01900c67bce': 'Cobham–Edmonds thesis. The complexity class NP, on the other hand, contains many problems that people would like to solve efficiently, but for which no efficient algorithm is known, such as the Boolean satisfiability problem, the Hamiltonian path problem and the vertex cover problem. Since deterministic Turing machines',
#  '5ad567055b96ef001a10adea': 'The complexity class P',
#  '5ad567055b96ef001a10adeb': 'complexity class P',
#  '5ad567055b96ef001a10adec': 'NP,',
#  '5ad567055b96ef001a10aded': 'Boolean satisfiability problem, the Hamiltonian path problem and the vertex cover problem.',
#  '5ad567055b96ef001a10adee': 'deterministic Turing machines',
#  '56e1ddfce3433e14004231d5': 'more efficient solutions',
#  '56e1ddfce3433e14004231d6': 'protein structure prediction',
#  '56e1ddfce3433e14004231d8': 'US$1,000,000',
#  '5ad568175b96ef001a10ae10': 'whether P equals NP',
#  '5ad568175b96ef001a10ae11': 'many important problems can be shown to have more efficient solutions',
#  '5ad568175b96ef001a10ae12': 'protein structure prediction in biology',
#  '5ad568175b96ef001a10ae13': 'P versus NP problem',
#  '5ad568175b96ef001a10ae14': 'US$1,000,000',
#  '56e1ded7cd28a01900c67bd4': 'Ladner',
#  '56e1ded7cd28a01900c67bd5': 'NP-intermediate problems.',
#  '56e1ded7cd28a01900c67bd6': 'The graph isomorphism problem, the discrete logarithm problem and the integer factorization problem',
#  '5ad568d35b96ef001a10ae1a': 'Ladner',
#  '5ad568d35b96ef001a10ae1b': 'graph isomorphism problem',
#  '5ad568d35b96ef001a10ae1c': 'The graph isomorphism problem, the discrete logarithm problem and the integer factorization problem',
#  '5ad568d35b96ef001a10ae1d': 'The graph isomorphism problem, the discrete logarithm problem and the integer factorization problem',
#  '56e1e9dfe3433e14004231fc': 'graph isomorphism',
#  '56e1e9dfe3433e14004231fd': 'NP-complete.',
#  '56e1e9dfe3433e14004231fe': 'polynomial hierarchy',
#  '56e1e9dfe3433e14004231ff': 'second level',
#  '56e1e9dfe3433e1400423200': 'Laszlo Babai and Eugene Luks',
#  '5ad569c05b96ef001a10ae36': 'determining whether two finite graphs are isomorphic',
#  '5ad569c05b96ef001a10ae37': 'The graph isomorphism',
#  '5ad569c05b96ef001a10ae38': 'whether the graph isomorphism problem is in P, NP-complete, or NP-intermediate.',
#  '5ad569c05b96ef001a10ae39': 'polynomial hierarchy',
#  '5ad569c05b96ef001a10ae3a': 'its second level',
#  '56e1ec83cd28a01900c67c0a': 'integer factorization',
#  '56e1ec83cd28a01900c67c0b': 'k',
#  '56e1ec83cd28a01900c67c0c': 'RSA algorithm.',
#  '56e1ec83cd28a01900c67c0e': 'general number field sieve',
#  '5ad56aea5b96ef001a10ae48': 'determining the prime factorization of a given integer',
#  '5ad56aea5b96ef001a10ae49': 'integer factorization',
#  '5ad56aea5b96ef001a10ae4a': 'integer factorization',
#  '5ad56aea5b96ef001a10ae4b': 'integer factorization problem is in NP and in co-NP (and even in UP and co-UP). If the problem is NP-complete,',
#  '5ad56aea5b96ef001a10ae4c': 'general number field sieve',
#  '56e1ee4de3433e1400423210': 'it is possible that all these complexity classes collapse to one class',
#  '56e1ee4de3433e1400423211': 'unequal',
#  '56e1ee4de3433e1400423212': 'P and PSPACE,',
#  '56e1ee4de3433e1400423214': 'any of these classes are unequal',
#  '5ad56bcd5b96ef001a10ae62': 'unequal',
#  '5ad56bcd5b96ef001a10ae63': 'unequal',
#  '5ad56bcd5b96ef001a10ae64': 'P and PSPACE,',
#  '5ad56bcd5b96ef001a10ae65': 'collapse to one class',
#  '5ad56bcd5b96ef001a10ae66': 'Proving that any of these classes are unequal',
#  '56e1efa0e3433e140042321a': 'co-NP',
#  '56e1efa0e3433e140042321b': 'reversed',
#  '56e1efa0e3433e140042321c': 'NP is not equal to co-NP;',
#  '56e1efa0e3433e140042321d': 'P is not equal to NP.',
#  '5ad56c6b5b96ef001a10ae6c': 'co-NP',
#  '5ad56c6b5b96ef001a10ae6d': 'reversed',
#  '5ad56c6b5b96ef001a10ae6e': 'NP is not equal to co-NP;',
#  '5ad56c6b5b96ef001a10ae6f': 'it has not yet been proven. It has been shown that if these two complexity classes are not equal then P is not equal to NP.',
#  '56e1f10ee3433e1400423222': 'L',
#  '56e1f10ee3433e1400423223': 'NL and NC, and it is not known if they are distinct or equal classes.',
#  '56e1f10ee3433e1400423224': 'many complexity classes',
#  '56e1f10ee3433e1400423225': 'NL and NC,',
#  '56e1f10ee3433e1400423226': 'it is not known if they are distinct or equal classes',
#  '5ad56d3e5b96ef001a10ae84': 'L',
#  '5ad56d3e5b96ef001a10ae85': 'distinct or equal classes',
#  '5ad56d3e5b96ef001a10ae86': 'distinct or equal classes',
#  '5ad56d3e5b96ef001a10ae87': 'NL and NC,',
#  '5ad56d3e5b96ef001a10ae88': 'it is not known if they are distinct or equal classes',
#  '56e1fc57e3433e140042322c': 'intractable problems',
#  '56e1fc57e3433e140042322f': 'polynomial time',
#  '56e1fc57e3433e1400423230': 'NP-complete problems',
#  '5ad56e5c5b96ef001a10ae9e': 'intractable problems',
#  '5ad56e5c5b96ef001a10ae9f': 'take too long',
#  '5ad56e5c5b96ef001a10aea0': 'Cobham–Edmonds thesis',
#  '5ad56e5c5b96ef001a10aea1': 'with a much faster computer',
#  '5ad56e5c5b96ef001a10aea2': 'polynomial time',
#  '56e1febfe3433e1400423236': 'Presburger',
#  '56e1febfe3433e1400423237': 'algorithms',
#  '56e1febfe3433e1400423238': 'NP-complete knapsack',
#  '56e1febfe3433e1400423239': 'over a wide range of sizes in less than quadratic time',
#  '56e1febfe3433e140042323a': 'NP-complete knapsack problem',
#  '5ad56ef05b96ef001a10aea8': 'Presburger',
#  '5ad56ef05b96ef001a10aea9': 'algorithms',
#  '5ad56ef05b96ef001a10aeaa': 'algorithms',
#  '5ad56ef05b96ef001a10aeab': 'large instances of the NP-complete Boolean satisfiability problem.',
#  '56e200e4cd28a01900c67c14': 'numerous foundations',
#  '56e200e4cd28a01900c67c15': 'Alan Turing',
#  '56e200e4cd28a01900c67c16': 'Turing machines',
#  '56e200e4cd28a01900c67c17': '1936',
#  '56e200e4cd28a01900c67c18': 'a very robust and flexible simplification of a computer',
#  '5ad56fe65b96ef001a10aec2': 'numerous foundations',
#  '5ad56fe65b96ef001a10aec3': 'Turing machines',
#  '5ad56fe65b96ef001a10aec4': 'Alan Turing',
#  '5ad56fe65b96ef001a10aec5': 'Turing machines',
#  '5ad56fe65b96ef001a10aec6': 'Turing machines',
#  '56e202e9e3433e1400423240': '"On the Computational Complexity of Algorithms"',
#  '56e202e9e3433e1400423241': 'Juris Hartmanis and Richard Stearns',
#  '56e202e9e3433e1400423242': '1965',
#  '56e202e9e3433e1400423243': 'time and space complexity',
#  '56e202e9e3433e1400423244': '1965',
#  '5ad570b25b96ef001a10aedc': '"On the Computational Complexity of Algorithms"',
#  '5ad570b25b96ef001a10aedd': 'Juris Hartmanis and Richard Stearns',
#  '5ad570b25b96ef001a10aede': '"On the Computational Complexity of Algorithms"',
#  '5ad570b25b96ef001a10aedf': 'time and space complexity',
#  '56e2042ecd28a01900c67c1e': "John Myhill's",
#  '56e2042ecd28a01900c67c1f': '1961',
#  '56e2042ecd28a01900c67c20': "Hisao Yamada's",
#  '5ad5719f5b96ef001a10aeec': "John Myhill's",
#  '5ad5719f5b96ef001a10aeed': "John Myhill's",
#  '5ad5719f5b96ef001a10aeee': '1961',
#  '5ad5719f5b96ef001a10aeef': "Hisao Yamada's",
#  '5ad5719f5b96ef001a10aef0': 'Boris Trakhtenbrot',
#  '56e20a27cd28a01900c67c24': 'input encoding',
#  '56e20a27cd28a01900c67c25': 'discussion',
#  '5ad53ac65b96ef001a10abac': 'input encoding',
#  '5ad53ac65b96ef001a10abad': 'input encoding',
#  '5ad53ac65b96ef001a10abae': 'complexity-theoretic theorems',
#  '5ad53ac65b96ef001a10abaf': 'input encoding, one tries to keep the discussion',
#  '56e20a3ae3433e140042324a': 'Manuel Blum',
#  '56e20a3ae3433e140042324b': 'speed-up theorem',
#  '56e20a3ae3433e140042324d': '"Reducibility Among Combinatorial Problems",',
#  '56e20a3ae3433e140042324e': '21',
#  '5ad572b15b96ef001a10af06': 'Manuel Blum',
#  '5ad572b15b96ef001a10af07': 'Manuel Blum',
#  '5ad572b15b96ef001a10af08': 'Stephen Cook',
#  '5ad572b15b96ef001a10af09': 'Richard Karp',
#  '5ad572b15b96ef001a10af0a': '"Reducibility Among Combinatorial Problems",',
#  '5705e26d75f01819005e76d4': 'SoCal,',
#  '5705e26d75f01819005e76d5': '10',
#  '5705e26d75f01819005e76d6': 'economic',
#  '5705e26d75f01819005e76d7': 'demographics and economic ties: Imperial, Los Angeles, Orange, Riverside, San Bernardino, San Diego, Santa Barbara, and Ventura.',
#  '5705e26d75f01819005e76d8': 'historical political divisions',
#  '5ad0178577cf76001a68698a': 'Kern and San Luis Obispo counties,',
#  '5ad0178577cf76001a68698b': 'Kern and San Luis Obispo counties,',
#  '5ad0178577cf76001a68698c': 'Southern California',
#  '5705e33f52bb89140068964c': 'greater Southern California Megaregion,',
#  '5705e33f52bb89140068964d': '11',
#  '5705e33f52bb89140068964e': 'Las Vegas, Nevada,',
#  '5705e33f52bb89140068964f': 'Mexican border',
#  '5705e33f52bb891400689650': 'Tijuana.',
#  '5ad0185a77cf76001a6869b8': 'greater Southern California Megaregion,',
#  '5ad0185a77cf76001a6869b9': 'Las Vegas, Nevada, and south across the Mexican border into Tijuana.',
#  '5ad0185a77cf76001a6869ba': '11 megaregions',
#  '5705e3f252bb89140068966a': 'Pacific coast',
#  '5705e3f252bb89140068966b': 'seven',
#  '5705e3f252bb89140068966c': '12 million',
#  '5705e3f252bb89140068966d': 'Los Angeles area',
#  '5705e3f252bb89140068966e': '17.5 million',
#  '5ad01a6277cf76001a686a0c': '60 percent',
#  '5ad01a6277cf76001a686a0d': 'MSAs: the Los Angeles metropolitan area, consisting of Los Angeles and Orange counties; the Inland Empire,',
#  '5ad01a6277cf76001a686a0e': 'over four million',
#  '5ad01a6277cf76001a686a0f': 'MSAs: the Los Angeles metropolitan area, consisting of Los Angeles and Orange counties; the Inland Empire,',
#  '5705e4fe75f01819005e7704': 'Colorado Desert',
#  '5705e4fe75f01819005e7705': 'Mojave Desert',
#  '5705e4fe75f01819005e7706': 'Mojave Desert',
#  '5705e4fe75f01819005e7707': 'Mexico–United States border.',
#  '5ad01c8877cf76001a686a64': 'Mexico–United States border.',
#  '5ad01c8877cf76001a686a65': 'Mexico–United States border.',
#  '5ad01c8877cf76001a686a66': 'south',
#  '5705e63175f01819005e7720': 'southern California',
#  '5705e63175f01819005e7721': '3,792,621',
#  '5705e63175f01819005e7722': 'Los Angeles',
#  '5705e63175f01819005e7723': 'San Diego,',
#  '5705e63175f01819005e7724': 'south',
#  '5ad01e4677cf76001a686aa6': 'Los Angeles and San Diego,',
#  '5ad01e4677cf76001a686aa7': 'Los Angeles',
#  '5ad01e4677cf76001a686aa8': 'San Diego,',
#  '5ad01e4677cf76001a686aa9': 'San Diego,',
#  '5705e99452bb891400689688': 'Los Angeles,',
#  '5705e99452bb891400689689': 'United States.',
#  '5705e99452bb89140068968a': 'Its counties',
#  '5705e99452bb89140068968b': 'top 15',
#  '5705e99452bb89140068968c': 'Los Angeles, Orange, San Diego, San Bernardino, and Riverside',
#  '5ad01f0f77cf76001a686ac2': 'Los Angeles, Orange, San Diego, San Bernardino, and Riverside',
#  '5ad01f0f77cf76001a686ac3': '15',
#  '5ad01f0f77cf76001a686ac4': 'five most populous in the state and all are in the top 15 most populous counties',
#  '5705eb3375f01819005e7764': 'Hollywood,',
#  '5705eb3375f01819005e7765': 'Los Angeles,',
#  '5705eb3375f01819005e7766': 'Walt Disney Company',
#  '5705eb3375f01819005e7767': 'music',
#  '5705eb3375f01819005e7768': 'Sony',
#  '5ad0206677cf76001a686afa': 'Walt Disney Company',
#  '5ad0206677cf76001a686afb': 'motion picture, television, and music',
#  '5ad0206677cf76001a686afc': 'Hollywood,',
#  '5ad0206677cf76001a686afd': 'Walt Disney Company (which also owns ABC), Sony Pictures, Universal, MGM, Paramount Pictures, 20th Century Fox, and Warner Brothers.',
#  '5705ec1675f01819005e776e': 'skateboard',
#  '5705ec1675f01819005e776f': 'Tony Hawk,',
#  '5705ec1675f01819005e7770': 'Shaun White',
#  '5705ec1675f01819005e7771': 'Oahu',
#  '5705ec1675f01819005e7772': 'Transpacific Yacht Race,',
#  '5ad0220a77cf76001a686b2a': 'Southern California',
#  '5ad0220a77cf76001a686b2b': 'professional surfers',
#  '5ad0220a77cf76001a686b2c': 'southern California.',
#  '5ad0220a77cf76001a686b2d': 'Trestles, Rincon, The Wedge, Huntington Beach, and Malibu,',
#  '5ad0220a77cf76001a686b2e': "America's Cup,",
#  '5705eccb52bb8914006896b8': 'Palm Springs',
#  '5705eccb52bb8914006896b9': 'popular beaches',
#  '5705eccb52bb8914006896ba': 'southern',
#  '5705eccb52bb8914006896bb': 'open spaces',
#  '5ad0228a77cf76001a686b58': 'Many locals and tourists',
#  '5ad0228a77cf76001a686b59': 'beaches',
#  '5ad0228a77cf76001a686b5a': 'southern California',
#  '5705edcd52bb8914006896ca': '37° 9\' 58.23"',
#  '5705edcd52bb8914006896cb': '11',
#  '5705edcd52bb8914006896cc': 'ten',
#  '5705edcd52bb8914006896cd': 'Tehachapi Mountains',
#  '5705edcd52bb8914006896ce': 'northern',
#  '5ad0297e77cf76001a686c3a': "California's north-south midway point",
#  '5ad0297e77cf76001a686c3b': 'midway point',
#  '5ad0297e77cf76001a686c3c': 'county lines',
#  '5ad0297e77cf76001a686c3d': 'southern California',
#  '5705eee952bb8914006896de': 'Mexico',
#  '5705eee952bb8914006896df': 'Alta California.',
#  '5705eee952bb8914006896e0': 'Los Angeles',
#  '5705eee952bb8914006896e1': 'the Compromise of 1850',
#  '5705eee952bb8914006896e2': 'free',
#  '5ad02cde77cf76001a686cc6': 'Mexico',
#  '5ad02cde77cf76001a686cc7': 'Californios of Monterey in the upper part and Los Angeles',
#  '5ad02cde77cf76001a686cc8': 'line of the Missouri Compromise.',
#  '5ad02cde77cf76001a686cc9': 'the Compromise of 1850',
#  '5705f09e75f01819005e77a4': 'inequitable taxes',
#  '5705f09e75f01819005e77a5': '"Cow Counties"',
#  '5705f09e75f01819005e77a6': 'three',
#  '5705f09e75f01819005e77a7': '75%',
#  '5705f09e75f01819005e77a8': 'Milton Latham.',
#  '5ad02e5d77cf76001a686d3a': 'Californios',
#  '5ad02e5d77cf76001a686d3b': 'the Pico Act of 1859,',
#  '5ad02e5d77cf76001a686d3c': 'John B. Weller.',
#  '5ad02e5d77cf76001a686d3d': 'John B. Weller.',
#  '5ad02e5d77cf76001a686d3e': 'Senator',
#  '5705f13d52bb8914006896f0': 'Los Angeles Times',
#  '5705f13d52bb8914006896f1': '1900',
#  '5705f13d52bb8914006896f2': '1999',
#  '5705f13d52bb8914006896f3': 'county—Imperial—to',
#  '5705f13d52bb8914006896f4': 'seven',
#  '5ad02ee077cf76001a686d58': '"the seven counties of Los Angeles, San Bernardino, Orange, Riverside, San Diego, Ventura and Santa Barbara."',
#  '5ad02ee077cf76001a686d59': 'a newer county—Imperial—to',
#  '5ad02ee077cf76001a686d5a': 'southern California',
#  '5705f36452bb891400689718': 'regional tourism groups',
#  '5705f36452bb891400689719': 'California State Automobile Association',
#  '5705f36452bb89140068971a': 'three-region',
#  '5705f36452bb89140068971b': 'Tehachapis,',
#  '5705f36452bb89140068971c': 'southern California region',
#  '5ad02ff177cf76001a686da2': 'AAA Auto Clubs',
#  '5ad02ff177cf76001a686da3': 'AAA Auto Clubs',
#  '5ad02ff177cf76001a686da4': 'geographical phrase',
#  '5ad02ff177cf76001a686da5': 'regional tourism groups',
#  '5705f7c875f01819005e77dc': 'third',
#  '5705f7c875f01819005e77dd': 'vast areas',
#  '5705f7c875f01819005e77de': 'suburban',
#  '5705f7c875f01819005e77df': 'highways',
#  '5705f7c875f01819005e77e0': 'international metropolitan region',
#  '5ad0316a77cf76001a686de4': 'Great Lakes Megalopolis and the Northeastern megalopolis.',
#  '5ad0316a77cf76001a686de5': 'Los Angeles, Orange County, San Diego, and Riverside-San Bernardino,',
#  '5ad0316a77cf76001a686de6': 'San Diego–Tijuana,',
#  '5705fb7f52bb891400689750': 'Camp Pendleton.',
#  '5705fb7f52bb891400689751': 'Inland Empire.',
#  '5705fb7f52bb891400689752': 'United States Census Bureau',
#  '5705fb7f52bb891400689753': 'Orange',
#  '5705fb7f52bb891400689754': '1990s',
#  '5ad0331877cf76001a686e16': 'exurbs',
#  '5ad0331877cf76001a686e17': 'L.A. and Orange Counties,',
#  '5ad0331877cf76001a686e18': 'exurbs',
#  '5ad0331877cf76001a686e19': 'Santa Maria and San Luis Obispo',
#  '5705fc3a52bb89140068976a': 'Mediterranean',
#  '5705fc3a52bb89140068976b': 'rain',
#  '5705fc3a52bb89140068976c': "90-60's",
#  '5705fc3a52bb89140068976d': 'very rare',
#  '5705fc3a52bb89140068976e': "70-50's",
#  '5ad0381a77cf76001a686e30': 'Mediterranean',
#  '5ad0381a77cf76001a686e31': 'all of Southern California',
#  '5ad0381a77cf76001a686e32': 'summers',
#  '5ad0381a77cf76001a686e33': 'snow',
#  '5705fd8475f01819005e7840': 'geologic, topographic, and natural ecosystem',
#  '5705fd8475f01819005e7841': 'Pacific Ocean',
#  '5705fd8475f01819005e7842': 'geologic, topographic, and natural ecosystem',
#  '5705fd8475f01819005e7843': 'Peninsular',
#  '5705fd8475f01819005e7844': 'Transverse and Peninsular Ranges',
#  '5ad0394877cf76001a686e56': 'geologic, topographic, and natural ecosystem landscapes',
#  '5ad0394877cf76001a686e57': 'Pacific Ocean',
#  '5ad0394877cf76001a686e58': 'Pacific Ocean',
#  '5ad0394877cf76001a686e59': 'Southern California',
#  '5705fec152bb89140068977a': '10,000',
#  '5705fec152bb89140068977b': '10,000',
#  '5705fec152bb89140068977c': '6.7',
#  '5705fec152bb89140068977d': 'property',
#  '5705fec152bb89140068977e': '$20 billion',
#  '5ad03c7377cf76001a686ebc': '1994',
#  '5ad03c7377cf76001a686ebd': 'Northridge earthquake',
#  '5ad03c7377cf76001a686ebe': '10,000',
#  '5ad03c7377cf76001a686ebf': '15–20',
#  '5705ffde52bb891400689784': 'San Andreas Fault,',
#  '5705ffde52bb891400689785': '6.7+',
#  '5705ffde52bb891400689786': 'the Puente Hills Fault,',
#  '5705ffde52bb891400689787': 'USGS',
#  '5705ffde52bb891400689788': 'Earthquake occurrence',
#  '5ad03d2277cf76001a686ecc': 'San Andreas Fault,',
#  '5ad03d2277cf76001a686ecd': 'San Andreas Fault,',
#  '5ad03d2277cf76001a686ece': 'California Earthquake forecast',
#  '5ad03d2277cf76001a686ecf': 'Earthquake occurrence in California.',
#  '570602fa52bb89140068979e': 'economically',
#  '570602fa52bb89140068979f': 'global',
#  '570602fa52bb8914006897a0': 'economic',
#  '5ad0410977cf76001a686efe': 'a city',
#  '5ad0410977cf76001a686eff': 'the hub of economic activity',
#  '5ad0410977cf76001a686f00': 'culturally, politically, and economically into distinctive regions',
#  '570603c475f01819005e7882': '2010',
#  '570603c475f01819005e7883': 'high growth rates',
#  '570603c475f01819005e7884': '10.0%',
#  '570603c475f01819005e7885': 'tech',
#  '570603c475f01819005e7886': 'Sacramento',
#  '5ad0421177cf76001a686f14': '2010 United States Census,',
#  '5ad0421177cf76001a686f15': '10.0%',
#  '5ad0421177cf76001a686f16': 'tech',
#  '5ad0421177cf76001a686f17': 'Sacramento',
#  '5706074552bb8914006897d4': 'Metropolitan Statistical Areas,',
#  '5706074552bb8914006897d5': 'two',
#  '5706074552bb8914006897d6': 'five million',
#  '5706074552bb8914006897d7': 'Southern Border Region.',
#  '5706074552bb8914006897d8': '17,786,419',
#  '5ad042cf77cf76001a686f24': 'Southern California',
#  '5ad042cf77cf76001a686f25': 'Southern California',
#  '5ad042cf77cf76001a686f26': 'Greater Los Angeles',
#  '5ad042cf77cf76001a686f27': 'San Diego–Tijuana',
#  '5ad042cf77cf76001a686f28': 'Santa Barbara, San Luis Obispo, and Bakersfield metropolitan areas.',
#  '570607f575f01819005e78b4': 'Los Angeles',
#  '570607f575f01819005e78b5': '100,000',
#  '570607f575f01819005e78b6': '34',
#  '570607f575f01819005e78b7': '100,000',
#  '570607f575f01819005e78b8': 'Riverside.',
#  '5ad0440877cf76001a686f3e': 'Los Angeles (at 3.7 million people) and San Diego',
#  '5ad0440877cf76001a686f3f': 'southern California',
#  '5ad0440877cf76001a686f40': 'southern California',
#  '5ad0440877cf76001a686f41': 'Los Angeles (at 3.7 million people) and San Diego',
#  '5ad0440877cf76001a686f42': 'Los Angeles',
#  '5706094b52bb8914006897de': 'petroleum',
#  '5706094b52bb8914006897df': 'Hollywood',
#  '5706094b52bb8914006897e0': 'housing bubble',
#  '5706094b52bb8914006897e1': 'diverse',
#  '5706094b52bb8914006897e2': 'heavily impacted',
#  '5ad044f077cf76001a686f58': "Southern California's",
#  '5ad044f077cf76001a686f59': 'the housing bubble',
#  '5ad044f077cf76001a686f5a': 'petroleum',
#  '5ad044f077cf76001a686f5b': 'Southern California',
#  '57060a1175f01819005e78d2': '1920s',
#  '57060a1175f01819005e78d3': 'suburbs',
#  '57060a1175f01819005e78d4': 'cattle',
#  '57060a1175f01819005e78d5': 'citrus',
#  '57060a1175f01819005e78d6': 'aerospace',
#  '5ad0458b77cf76001a686f72': 'motion pictures, petroleum and aircraft manufacturing',
#  '5ad0458b77cf76001a686f73': 'cattle and citrus',
#  '5ad0458b77cf76001a686f74': 'military spending cutbacks',
#  '5ad0458b77cf76001a686f75': '1920s',
#  '57060a6e52bb8914006897f8': 'major business districts',
#  '57060a6e52bb8914006897f9': 'Central business districts',
#  '57060a6e52bb8914006897fa': 'Downtown Los Angeles, Downtown San Diego,',
#  '5ad0461477cf76001a686f7a': '(CBD)',
#  '5ad0461477cf76001a686f7b': 'Central business districts',
#  '5ad0461477cf76001a686f7c': '(CBD)',
#  '57060cc352bb89140068980e': 'business districts',
#  '57060cc352bb89140068980f': 'Los Angeles',
#  '57060cc352bb891400689810': 'San Fernando Valley.',
#  '57060cc352bb891400689811': 'Los Angeles',
#  '5ad0470477cf76001a686f80': 'Downtown Burbank, Downtown Santa Monica, Downtown Glendale and Downtown Long Beach. Los Angeles itself has many business districts including the Downtown Los Angeles central business district',
#  '5ad0470477cf76001a686f81': 'Los Angeles central business district',
#  '5ad0470477cf76001a686f82': 'Downtown Los Angeles central business district',
#  '57060df252bb891400689820': 'business districts',
#  '57060df252bb891400689821': 'Downtown Riverside.',
#  '57060df252bb891400689822': 'Hospitality Business/Financial Centre,',
#  '5ad0475c77cf76001a686f86': 'Downtown San Bernardino, Hospitality Business/Financial Centre,',
#  '5ad0475c77cf76001a686f87': 'Downtown San Bernardino, Hospitality Business/Financial Centre,',
#  '57060eaf75f01819005e7910': 'Orange County',
#  '57060eaf75f01819005e7911': 'University of California, Irvine.',
#  '57060eaf75f01819005e7912': 'Irvine Tech Center',
#  '57060eaf75f01819005e7913': 'South Coast Metro',
#  '57060eaf75f01819005e7914': 'rapidly',
#  '5ad0483977cf76001a686f8a': 'Orange County',
#  '5ad0483977cf76001a686f8b': 'Newport Center districts;',
#  '5ad0483977cf76001a686f8c': 'Irvine Spectrum, West Irvine, and international corporations',
#  '5ad0483977cf76001a686f8d': 'West Irvine',
#  '57060f3e75f01819005e7922': 'Downtown San Diego',
#  '57060f3e75f01819005e7923': 'Northern San Diego',
#  '57060f3e75f01819005e7924': 'North County',
#  '57060f3e75f01819005e7925': 'San Diego',
#  '5ad04b2377cf76001a686f92': 'Downtown San Diego',
#  '5ad04b2377cf76001a686f93': 'Most of these districts are located in Northern San Diego and some within North County regions.',
#  '5ad04b2377cf76001a686f94': 'Carmel Valley, Del Mar Heights, Mission Valley, Rancho Bernardo, Sorrento Mesa, and University City.',
#  '570610b275f01819005e792a': 'Los Angeles International Airport,',
#  '570610b275f01819005e792b': 'passenger volume',
#  '570610b275f01819005e792c': 'third',
#  '570610b275f01819005e792d': 'San Diego International Airport',
#  '570610b275f01819005e792e': 'Van Nuys Airport,',
#  '5ad04bfc77cf76001a686f98': 'Los Angeles International Airport,',
#  '5ad04bfc77cf76001a686f99': 'San Diego International Airport',
#  '5ad04bfc77cf76001a686f9a': 'Van Nuys Airport,',
#  '5ad04bfc77cf76001a686f9b': 'Orange County, Bakersfield, Ontario, Burbank and Long Beach;',
#  '5706111a52bb89140068984c': 'Metrolink,',
#  '5706111a52bb89140068984d': 'seven',
#  '5706111a52bb89140068984e': 'Six',
#  '5706111a52bb89140068984f': 'San Diego',
#  '5ad04d3077cf76001a686fa0': 'Downtown Los Angeles,',
#  '5ad04d3077cf76001a686fa1': 'Metrolink,',
#  '5ad04d3077cf76001a686fa2': 'San Diego',
#  '570611c475f01819005e793c': 'Port of Los Angeles,',
#  '570611c475f01819005e793d': 'Port of Long Beach,',
#  '570611c475f01819005e793e': 'Southern California',
#  '5ad04de377cf76001a686fa6': 'Port of Los Angeles,',
#  '5ad04de377cf76001a686fa7': 'Port of Long Beach,',
#  '5ad04de377cf76001a686fa8': 'Port of Long Beach,',
#  '5ad04de377cf76001a686fa9': 'Port of Los Angeles,',
#  '5706139252bb891400689864': 'The Tech Coast',
#  '5706139252bb891400689865': 'research universities',
#  '5706139252bb891400689866': 'private',
#  '5706139252bb891400689867': '5',
#  '5706139252bb891400689868': '12',
#  '5ad04ecf77cf76001a686fae': '(Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego);',
#  '5ad04ecf77cf76001a686faf': '5',
#  '5ad04ecf77cf76001a686fb0': '12',
#  '5ad04ecf77cf76001a686fb1': 'University of Redlands, University of San Diego,',
#  '5ad04ecf77cf76001a686fb2': 'Northridge,',
#  '5706143575f01819005e7950': 'NFL',
#  '5706143575f01819005e7951': 'NBA',
#  '5706143575f01819005e7952': 'MLB',
#  '5706143575f01819005e7953': '(Los Angeles Kings,',
#  '5706143575f01819005e7954': '(LA Galaxy).',
#  '5ad04f7977cf76001a686fb8': '(Los Angeles Rams, San Diego Chargers);',
#  '5ad04f7977cf76001a686fb9': '(Los Angeles Rams, San Diego Chargers);',
#  '5ad04f7977cf76001a686fba': '(Los Angeles Rams, San Diego Chargers);',
#  '5ad04f7977cf76001a686fbb': '(Los Angeles Rams, San Diego Chargers);',
#  '5ad04f7977cf76001a686fbc': '(Los Angeles Rams, San Diego Chargers);',
#  '5706149552bb891400689880': 'Chivas',
#  '5706149552bb891400689881': 'two',
#  '5706149552bb891400689882': '2014',
#  '5706149552bb891400689883': 'StubHub Center',
#  '5706149552bb891400689884': '2018',
#  '5ad050c877cf76001a686fc2': 'two',
#  '5ad050c877cf76001a686fc3': 'LA Galaxy and Chivas USA',
#  '5ad050c877cf76001a686fc4': '2014 MLS season,',
#  '5ad050c877cf76001a686fc5': '2018',
#  '570614ff52bb89140068988a': 'College sports',
#  '570614ff52bb89140068988b': 'USC Trojans',
#  '570614ff52bb89140068988c': 'Trojans',
#  '570614ff52bb89140068988d': 'Pac-12',
#  '570614ff52bb89140068988e': 'Pac-12',
#  '5ad0511577cf76001a686fca': 'UCLA Bruins',
#  '5ad0511577cf76001a686fcb': 'UCLA Bruins',
#  '5ad0511577cf76001a686fcc': 'Pac-12',
#  '5706155352bb891400689894': 'Rugby',
#  '5706155352bb891400689895': 'high school',
#  '5706155352bb891400689896': 'an official school sport',
#  '5ad051be77cf76001a686fd0': 'Rugby',
#  '57092322efce8f15003a7db0': 'BSkyB',
#  '57092322efce8f15003a7db1': 'BSkyB',
#  '57092322efce8f15003a7db2': '2014',
#  '57092322efce8f15003a7db3': 'British Sky Broadcasting Group plc',
#  '57092322efce8f15003a7db4': 'British Sky Broadcasting Limited',
#  '5a2c08aebfd06b001a5ae989': 'BSkyB',
#  '5a2c08aebfd06b001a5ae98a': 'BSkyB',
#  '5a2c08aebfd06b001a5ae98b': '2014',
#  '5a2c08aebfd06b001a5ae98c': 'November 1990',
#  '5a2c08aebfd06b001a5ae98d': 'Sky UK Limited,',
#  '57094a79efce8f15003a7dc4': '2006',
#  '57094a79efce8f15003a7dc5': 'two',
#  '57094a79efce8f15003a7dc6': 'Setanta Sports',
#  '57094a79efce8f15003a7dc7': '£1.3bn',
#  '5a2c0c2fbfd06b001a5ae99b': "BSkyB's",
#  '5a2c0c2fbfd06b001a5ae99c': 'two',
#  '5a2c0c2fbfd06b001a5ae99d': 'four',
#  '5a2c0c2fbfd06b001a5ae99e': '£1bn',
#  '5a2c0c2fbfd06b001a5ae99f': '3D',
#  '57094b4f9928a814004714f6': 'ONdigital consortium,',
#  '57094b4f9928a814004714f7': "ITV Digital's",
#  '57094b4f9928a814004714f8': 'three',
#  '57094b4f9928a814004714f9': 'Sky Three',
#  '57094b4f9928a814004714fa': "'Pick TV'",
#  '5a2c14b4bfd06b001a5ae9d3': 'ONdigital consortium,',
#  '5a2c14b4bfd06b001a5ae9d4': 'Sky Three',
#  '5a2c14b4bfd06b001a5ae9d5': 'Sky News, Sky Three, and Sky Sports News. Initially BSkyB provided Sky Travel to the service. However, this was replaced by Sky Three',
#  '5a2c14b4bfd06b001a5ae9d6': "ITV Digital's",
#  '5a2c14b4bfd06b001a5ae9d7': "'Pick TV'",
#  '57094ca7efce8f15003a7dd6': 'Sky+ PVR',
#  '57094ca7efce8f15003a7dd7': 'September 2007,',
#  '57094ca7efce8f15003a7dd8': 'can still pay a monthly fee',
#  '57094ca7efce8f15003a7dd9': 'January 2010',
#  '57094ca7efce8f15003a7dda': 'Sky+HD Box',
#  '5a2c16e3bfd06b001a5ae9e7': 'Sky+ PVR with their service; waiving the charge for subscribers whose package included two or more premium channels. This changed as from 1 July 2007, and now customers that have Sky+ and subscribe to any BSkyB subscription package get Sky+',
#  '5a2c16e3bfd06b001a5ae9e8': 'September 2007,',
#  '5a2c16e3bfd06b001a5ae9e9': 'a monthly fee',
#  '5a2c16e3bfd06b001a5ae9ea': '1 July 2007,',
#  '5a2c16e3bfd06b001a5ae9eb': 'Multiroom box,',
#  '57094d489928a8140047150a': 'VideoGuard',
#  '57094d489928a8140047150b': 'NDS,',
#  '57094d489928a8140047150c': 'Cisco Systems company.',
#  '57094d489928a8140047150d': 'BSkyB',
#  '57094d489928a8140047150e': 'Sky+).',
#  '5a2c3a5cbfd06b001a5aea79': 'VideoGuard',
#  '5a2c3a5cbfd06b001a5aea7a': 'BSkyB',
#  '5a2c3a5cbfd06b001a5aea7b': 'conditional-access modules',
#  '5a2c3a5cbfd06b001a5aea7c': 'Cisco Systems',
#  '5a2c3a5cbfd06b001a5aea7d': 'Sky+).',
#  '570953a7efce8f15003a7dfe': '2007',
#  ...}

# %%
dev_data[0]
# Out:
# {'qas': [{'question': 'In what country is Normandy located?',
#    'id': '56ddde6b9a695914005b9628',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': False},
#   {'question': 'When were the Normans in Normandy?',
#    'id': '56ddde6b9a695914005b9629',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': False},
#   {'question': 'From which countries did the Norse originate?',
#    'id': '56ddde6b9a695914005b962a',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': False},
#   {'question': 'Who was the Norse leader?',
#    'id': '56ddde6b9a695914005b962b',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': False},
#   {'question': 'What century did the Normans first gain their separate identity?',
#    'id': '56ddde6b9a695914005b962c',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': False},
#   {'plausible_answers': [{'text': 'Normans', 'answer_start': 4}],
#    'question': "Who gave their name to Normandy in the 1000's and 1100's",
#    'id': '5ad39d53604f3c001a3fe8d1',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': True},
#   {'plausible_answers': [{'text': 'Normandy', 'answer_start': 137}],
#    'question': 'What is France a region of?',
#    'id': '5ad39d53604f3c001a3fe8d2',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': True},
#   {'plausible_answers': [{'text': 'Rollo', 'answer_start': 308}],
#    'question': 'Who did King Charles III swear fealty to?',
#    'id': '5ad39d53604f3c001a3fe8d3',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': True},
#   {'plausible_answers': [{'text': '10th century', 'answer_start': 671}],
#    'question': 'When did the Frankish identity emerge?',
#    'id': '5ad39d53604f3c001a3fe8d4',
#    'answers': [{'text': ' ', 'answer_start': 0}],
#    'is_impossible': True}],
#  'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.'}

# %%
submission = {pred['id']: pred['answer'] for pred in preds}

# %%
with open('data/dev-v2.0.json', 'r') as f:
    dev_data = json.load(f)
    
dev_data = [item for topic in dev_data['data'] for item in topic['paragraphs'] ]

# %%
model.predict(dev_data[:2])
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
#  47%|████▋     | 8/17 [00:00<00:00, 76.37it/s]
# Converting to features started.
# 100%|██████████| 17/17 [00:00<00:00, 60.44it/s]
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# [{'id': '56ddde6b9a695914005b9628', 'answer': 'France.'},
#  {'id': '56ddde6b9a695914005b9629', 'answer': '10th and 11th centuries'},
#  {'id': '56ddde6b9a695914005b962a', 'answer': 'Denmark, Iceland and Norway'},
#  {'id': '56ddde6b9a695914005b962b', 'answer': 'Rollo,'},
#  {'id': '56ddde6b9a695914005b962c', 'answer': '10th'},
#  {'id': '5ad39d53604f3c001a3fe8d1', 'answer': 'The Normans'},
#  {'id': '5ad39d53604f3c001a3fe8d2', 'answer': 'Normandy,'},
#  {'id': '5ad39d53604f3c001a3fe8d3', 'answer': 'West Francia.'},
#  {'id': '5ad39d53604f3c001a3fe8d4',
#   'answer': 'first half of the 10th century'},
#  {'id': '56dddf4066d3e219004dad5f', 'answer': 'William the Conqueror,'},
#  {'id': '56dddf4066d3e219004dad60', 'answer': 'Richard I'},
#  {'id': '56dddf4066d3e219004dad61', 'answer': 'Catholic'},
#  {'id': '5ad3a266604f3c001a3fea27',
#   'answer': 'political, cultural and military'},
#  {'id': '5ad3a266604f3c001a3fea28', 'answer': 'The Normans'},
#  {'id': '5ad3a266604f3c001a3fea29', 'answer': 'The Normans'},
#  {'id': '5ad3a266604f3c001a3fea2a', 'answer': 'Richard I'},
#  {'id': '5ad3a266604f3c001a3fea2b', 'answer': 'Antioch'}]
